# %%
from bioacoustics.data import (
    load_metadata,
    load_audio,
    get_labels,
)

from bioacoustics.features import get_features, get_spectrogram

from bioacoustics.visualization import plot_spectrogram

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df_train, df_train_soundscapes, df_taxonomy = load_metadata()
y_class, y_primary = get_labels(df_train, df_taxonomy)
y_class_soundscapes, y_primary_soundscapes = get_labels(df_train_soundscapes, df_taxonomy)

# %%
example_audio = load_audio(df_train.iloc[0])

# %%
example_audio = load_audio(df_train_soundscapes.iloc[0])

# %%
get_features(example_audio)
# Out:
# spec_min   -41.699825
# spec_max    38.300175
# dtype: float32

# %%
S_db, frequencies, times = get_spectrogram(example_audio, n_fft=2048)
plot_spectrogram(S_db, frequencies, times)

# %% [markdown]
# Features that can be extracted from sound:
# - raw signal features:
#     - mean, variance
#     - zero-crossing rate
# - frequency based:
#     - spectral features
#         - spectral centroid
#         - spectral bandwidth
#         - spectral rolloff ?
#     - MFCC: Mel_Frequency Cepstral Coefficients ...
# - time-frequency features:
#     - spectrogram stats
#     - chroma features
