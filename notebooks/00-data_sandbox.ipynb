# %% [markdown]
# # Data Loading

# %% [markdown]
# ## Dataset Description

# %% [markdown]
# Your challenge in this competition is to identify which species (birds, amphibians, mammals, reptiles, insects) are calling in recordings made in the Brazilian Pantanal. This is an important task for scientists who monitor animal populations for conservation purposes. More accurate solutions could enable more comprehensive monitoring.
#
# This competition uses a hidden test set. When your submitted notebook is scored, the actual test data will be made available to your notebook.

# %% [markdown]
# ### Files

# %% [markdown]
# `train_audio/` The training data consists of short recordings of individual bird, amphibian, reptile, mammal, and insect sounds generously uploaded by users of xeno-canto.org and iNaturalist. These files have been resampled to 32 kHz where applicable to match the test set audio and converted to the ogg format. Filenames consist of [collection][file_id_in_collection].ogg. The training data should have nearly all relevant files; we expect there is no benefit to looking for more on xeno-canto.org or iNaturalist and appreciate your cooperation in limiting the burden on their servers. If you do, please make sure to adhere to the scraping rules of these data portals.

# %% [markdown]
# `test_soundscapes/` When you submit a notebook, the test_soundscapes directory will be populated with approximately 600 recordings to be used for scoring. They are 1 minute long and in ogg audio format, resampled to 32 kHz. The file names have the general form of BC2026_Test_<file ID>_<site>_<date>_<time in UTC>.ogg (e.g., file BC2026_Test_0001_S05_20250227_010002.ogg has file ID 0001, was recorded at site S05 on Feb 27 2025 at 01:00 UTC). It should take your submission notebook approximately five minutes to load all the test soundscapes. Not all species from the training data actually occur in the test data.

# %% [markdown]
# `train_soundscapes/` Additional audio data from roughly the same recording locations as the test_soundscapes. Filenames follow the same naming convention as the test_soundscapes; although some recording sites overlap between train and test, precise recording dates and times do NOT overlap with recordings of the hidden test data. This year, some of the train_soundscapes have been labeled by expert annotators, and we provide the ground truth for a subset of train_soundscapes in train_soundscapes_labels.csv with columns filename referencing the soundscape file, start and end referencing the 5-second segment for which column primary_label provides a semicolon-separated list of species codes that have been marked as present in this segment.

# %% [markdown]
# **Important note:** Some species with occurrences in the hidden test data might only have train samples in the labeled portion of train_soundscapes and not in the train_audio (XC and iNat data). However, not all species from train_soundscapes have occurrences in the test_soundscapes.

# %% [markdown]
# `train.csv` A wide range of metadata is provided for the training data. The most directly relevant fields are:
#
# - primary_label: A code for the species (eBird code for birds, iNaturalist taxon ID for non-birds). You can review detailed information about the species by appending codes to eBird and iNaturalist taxon URL, such as https://ebird.org/species/brnowl for the Barn Owl or https://www.inaturalist.org/taxa/41970 for the Jaguar. Not all species have their own pages; some links might fail.
#
# - secondary_labels: List of species labels that have been marked by recordists to also occur in the recording. Can be incomplete.
#
# - latitude & longitude: Coordinates for where the recording was taken. Some bird species may have local call 'dialects,' so you may want to seek geographic diversity in your training data.
#
# - author: The user who provided the recording. Unknown if no name was provided.
#
# - filename: The name of the associated audio file.
#
# - rating: Values in 1..5 (1 - low quality, 5 - high quality; 0.5 reduction in rating when background species are present) provided by users of Xeno-canto; 0 implies no rating is available; iNaturalist does not provide quality ratings.
#
# - collection: Either XC or iNat, indicating which collection the recording was taken from. Filenames also reference the collection and the ID within that collection.

# %% [markdown]
# `sample_submission.csv` A valid sample submission.
#
# - row_id: A slug of [soundscape_filename]_[end_time] for the prediction; e.g., Segment 00:15-00:20 of 1-minute test soundscape BC2026_Test_0001_S05_20250227_010002.ogg has row ID BC2026_Test_0001_S05_20250227_010002_20.
#
# - [species_id]: There are 234 species ID columns. You will need to predict the probability of the presence of each species for each row.
# taxonomy.csv - Data on the different species, including iNaturalist taxon ID and class name (Aves, Amphibia, Mammalia, Insecta, Reptilia). Most insect species in this competition have not been identified on species level and instead occur as sonotypes (e.g., 47158son16 as insect sonotype 16); these sonotypes are treated as classes despite the lack of species ID and some of them also occur in the test data. The 234 rows of this file represent the 234 class columns in the submission file. primary_label specifies the submission file column name.

# %% [markdown]
# `recording_location.txt` - Some high-level information on the recording location (Pantanal, Brazil).

# %%
import librosa
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from pathlib import Path

DATA_DIR = Path("../data")

# %%
df_train = pd.read_csv(DATA_DIR/"train.csv")
df_train_soundscapes = pd.read_csv(DATA_DIR/"train_soundscapes_labels.csv")
df_taxonomy = pd.read_csv(DATA_DIR/"taxonomy.csv")

# %%
df_train
# Out:
#       primary_label secondary_labels               type  latitude  longitude  \
# 0           1161364               []                 []  -22.7562   -46.8666
# 1           1161364               []                 []  -22.7558   -46.8700
# 2           1161364               []                 []  -22.7547   -46.8728
# 3           1161364               []                 []  -22.7547   -46.8728
# 4           1161364               []                 []  -22.7426   -46.8985
# ...             ...              ...                ...       ...        ...
# 35544       yeofly1               []           ['call']   -6.7281   -76.4181
# 35545       yeofly1               []  ['call', ' song']  -16.0538   -49.6040
# 35546       yeofly1               []           ['song']    5.9002   -74.8485
# 35547       yeofly1               []           ['song']    3.3821   -61.4464
# 35548       yeofly1               []           ['song']  -19.4144   -42.4151
#
#                 scientific_name            common_name class_name  \
# 0                  Guyalna cuta           Guyalna cuta    Insecta
# 1                  Guyalna cuta           Guyalna cuta    Insecta
# 2                  Guyalna cuta           Guyalna cuta    Insecta
# 3                  Guyalna cuta           Guyalna cuta    Insecta
# 4                  Guyalna cuta           Guyalna cuta    Insecta
# ...                         ...                    ...        ...
# 35544  Tolmomyias sulphurescens  Yellow-olive Flatbill       Aves
# 35545  Tolmomyias sulphurescens  Yellow-olive Flatbill       Aves
# 35546  Tolmomyias sulphurescens  Yellow-olive Flatbill       Aves
# 35547  Tolmomyias sulphurescens  Yellow-olive Flatbill       Aves
# 35548  Tolmomyias sulphurescens  Yellow-olive Flatbill       Aves
#
#        inat_taxon_id                      author   license  rating  \
# 0            1161364               Lucas Barbosa  cc-by-nc     0.0
# 1            1161364               Lucas Barbosa  cc-by-nc     0.0
# 2            1161364               Lucas Barbosa  cc-by-nc     0.0
# 3            1161364               Lucas Barbosa  cc-by-nc     0.0
# 4            1161364               Lucas Barbosa  cc-by-nc     0.0
# ...              ...                         ...       ...     ...
# 35544          16567               GABRIEL LEITE  by-nc-sa     4.0
# 35545          16567  JAYRSON ARAUJO DE OLIVEIRA  by-nc-sa     5.0
# 35546          16567              Jerome Fischer  by-nc-sa     4.0
# 35547          16567               GABRIEL LEITE  by-nc-sa     4.0
# 35548          16567                 Roney Souza  by-nc-sa     5.0
#
#                                                      url  \
# 0      https://static.inaturalist.org/sounds/1216197....
# 1      https://static.inaturalist.org/sounds/1114648....
# 2      https://static.inaturalist.org/sounds/810195.m...
# 3      https://static.inaturalist.org/sounds/818781.m...
# 4      https://static.inaturalist.org/sounds/556514.m...
# ...                                                  ...
# 35544             https://xeno-canto.org/762473/download
# 35545             https://xeno-canto.org/818328/download
# 35546             https://xeno-canto.org/425545/download
# 35547             https://xeno-canto.org/456230/download
# 35548             https://xeno-canto.org/298884/download
#
#                       filename collection
# 0      1161364/iNat1216197.ogg       iNat
# 1      1161364/iNat1114648.ogg       iNat
# 2       1161364/iNat810195.ogg       iNat
# 3       1161364/iNat818781.ogg       iNat
# 4       1161364/iNat556514.ogg       iNat
# ...                        ...        ...
# 35544     yeofly1/XC762473.ogg         XC
# 35545     yeofly1/XC818328.ogg         XC
# 35546     yeofly1/XC425545.ogg         XC
# 35547     yeofly1/XC456230.ogg         XC
# 35548     yeofly1/XC298884.ogg         XC
#
# [35549 rows x 15 columns]

# %%
df_train_soundscapes
# Out:
#                                        filename     start       end  \
# 0     BC2026_Train_0039_S22_20211231_201500.ogg  00:00:00  00:00:05
# 1     BC2026_Train_0039_S22_20211231_201500.ogg  00:00:05  00:00:10
# 2     BC2026_Train_0039_S22_20211231_201500.ogg  00:00:10  00:00:15
# 3     BC2026_Train_0039_S22_20211231_201500.ogg  00:00:15  00:00:20
# 4     BC2026_Train_0039_S22_20211231_201500.ogg  00:00:20  00:00:25
# ...                                         ...       ...       ...
# 1473  BC2026_Train_0055_S22_20220219_200000.ogg  00:00:35  00:00:40
# 1474  BC2026_Train_0055_S22_20220219_200000.ogg  00:00:40  00:00:45
# 1475  BC2026_Train_0055_S22_20220219_200000.ogg  00:00:45  00:00:50
# 1476  BC2026_Train_0055_S22_20220219_200000.ogg  00:00:50  00:00:55
# 1477  BC2026_Train_0055_S22_20220219_200000.ogg  00:00:55  00:01:00
#
#                        primary_label
# 0     22961;23158;24321;517063;65380
# 1     22961;23158;24321;517063;65380
# 2     22961;23158;24321;517063;65380
# 3     22961;23158;24321;517063;65380
# 4     22961;23158;24321;517063;65380
# ...                              ...
# 1473                    555146;65380
# 1474                   517063;555146
# 1475                   517063;555146
# 1476             517063;555146;66971
# 1477             517063;555146;66971
#
# [1478 rows x 4 columns]

# %%
df_taxonomy
# Out:
#     primary_label  inat_taxon_id           scientific_name  \
# 0         1161364        1161364              Guyalna cuta
# 1          116570         116570             Caiman yacare
# 2         1176823        1176823    Leptodactylus luctator
# 3         1491113        1491113         Adenomera guarani
# 4         1595929        1595929         Lysapsus limellum
# ..            ...            ...                       ...
# 229       yebela1          16714       Elaenia flavogaster
# 230        yecmac          73272      Primolius auricollis
# 231        yecpar          19215        Brotogeris chiriri
# 232       yehcar1        1432779       Daptrius chimachima
# 233       yeofly1          16567  Tolmomyias sulphurescens
#
#                     common_name class_name
# 0                  Guyalna cuta    Insecta
# 1    Southern Spectacled Caiman   Reptilia
# 2                 Wrestler Frog   Amphibia
# 3      Guaraní leaf-litter frog   Amphibia
# 4        Uruguay Harlequin Frog   Amphibia
# ..                          ...        ...
# 229      Yellow-bellied Elaenia       Aves
# 230       Golden-collared Macaw       Aves
# 231   Yellow-chevroned Parakeet       Aves
# 232      Yellow-headed Caracara       Aves
# 233       Yellow-olive Flatbill       Aves
#
# [234 rows x 5 columns]

# %% [markdown]
# For now I am going to ignore the secondary labels as they concern only a small fraction of the data.

# %%
print(
    f"Percentage of train audio with secondary labels: {(df_train['secondary_labels'] != '[]').sum() / len(df_train) * 100:.2f}%"
)
# Out:
# Percentage of train audio with secondary labels: 12.30%

# %% [markdown]
# There are very many different types of calls, songs, etc... It would likely make sense combine them into different categories e.g. songs, calls, etc so that there can be clearer similarities between the calories. I've listed them here.

# %%
import ast

list_types = df_train["type"].unique().tolist()
list_types = [ast.literal_eval(lst) for lst in list_types]
possible_types = set(x for sublist in list_types for x in sublist)
print(list_types)
print(possible_types)
# Out:
# [[], ['uncertain'], ['advertisement call'], ['territorial call'], ['flight call'], ['advertisement call', ' chorus'], ['reproductive call ?'], ['alarm call'], ['call'], ['mating call'], ['social call'], ['advertisement call', ' territorial call'], ['song'], ['call', ' mechanical sound'], ['mechanical sound'], ['sniffing'], ['call', ' song'], ['call', ' scolding'], ['canto'], ['call', ' subsong'], ['alarm call', ' llamadas de contacto'], ['voz de contacto de adulto.'], ['song', ' llamado de adulto.'], ['voz de contacto de pichón.'], ['duet', ' song'], ['duet'], ['alarm call', ' call'], ['aberrant'], ['dueto'], ['duet', ' song', ' song in duet'], ['song', ' duo'], ['fast low call'], ['chamado'], ['dawn song'], ['call', ' duet'], ['call', ' wing sound'], ['alarm call', ' call', ' juvenile call'], ['song', ' long song'], ['song', ' complex song'], ['song', " 'laughing' song"], ['song', " 'barking' song"], ['song', ' simple song'], ['call', ' dawn song', ' duet'], ['call', ' duet', ' song'], ['song', ' territorial song'], ['call', ' cackling calls'], ['subsong'], ['call?'], ['song', ' laughing song'], ['call', ' song', ' song/call'], ['song', ' 5-noted song'], ['song', ' agitated song'], ['song', ' 4-noted song'], ['duet', ' dawn duet'], ['call', ' cackling call', ' female?'], ['alarm call', ' alarm call of an adult'], ['song?'], ['song', ' "'], ['song', ' "laughing" song'], ['song', ' myadestes occidentalis'], ['call', ' calls'], ['begging call'], ['begging call', ' call'], ['chase call'], ['call', ' day song'], ['subsong', ' chase call'], ['drumming', ' song'], ['begging call', ' drumming'], ['duet', ' song', ' duet song'], ['call', ' whistle call'], ['duet', ' flight call', ' song', ' duet.'], ['contact call'], ['call', ' various different calls and whistles'], ['song', ' subsong'], ['call', ' calls', ' females'], ['call', ' contact call'], ['call', ' song', ' two different calls'], ['song', ' dueto'], ['alarm call', ' song'], ['song', ' short and long songs'], ['begging call', ' song'], ['vocalizations by a young bird learning to sing'], ['duet', ' song', ' subsong'], ['song', ' immature song'], ['flight call', ' song'], ['alarm call', ' flight call'], ['call', ' flight call'], ['canto de voo'], ['call', ' take-off calls'], ['call', ' (flight?) calls'], ['call', ' llamado de cría'], ['nocturnal flight call'], ['flight call', ' flight calls'], ['call', ' song', ' call and song in flight'], ['call', ' Musical calls'], ['call', ' contact calls'], ['song', ' estridulación'], ['call', ' flight call', ' song'], ['flight song'], ['call', ' calls on takling flight'], ['flight call', ' frogs'], ['call', ' song', ' contact call'], ['call', ' contacts call'], ['song', " 'cascade' and song", ' pb'], ['call', ' song', ' natural song', " then 'cascade' and call after pb"], ['call', ' chatters calls'], ['chatter from flock after playback (like natural)'], ['call', ' song', ' excitement chatter'], ['chatter'], ['alarm call', ' anfibios'], ['aberrant', ' call', ' duet', ' song', ' Complex song'], ['alarm call', ' call', ' song'], ['alarm call', ' call', ' duet', ' subsong'], ['call', ' duet', ' song', ' duet song. calls'], ['call', ' song', ' subsong'], ['call', ' excited call'], ['call', ' agitated calls'], ['alarm call', ' alarm calls'], ['call', ' duet', ' calls'], ['call', ' duet', ' flight call', ' wing-flapping'], ['canto em voo'], ['call', ' calls', ' perched'], ['call', ' displaying'], ['alarm call', ' subsong'], ['call', ' calls', ' interaction calls'], ['song', ' domestic dogs'], ['call', ' flight call', ' very agitated calls of juvenile'], ['call', ' calls in flight.'], ['song', ' song in flight'], ['song', ' agitated song in flight'], ['wing sound'], ['call', ' song', ' song. calls.'], ['call', ' interaction calls'], ['call', ' duet', ' duets'], ['call', ' 2 call types'], ['aberrant call'], ['dawn song', ' song'], ['song', ' morning song'], ['call', ' squabble in flight'], ['call', ' chase call', ' wing sound'], ['call', ' huit note ...
# {'', ' growl', ' territorial calls', ' Social contact call', ' three different calls', ' (alarm?) calls', ' various different calls and whistles', ' various calls', ' nestling calls', ' scream', 'chase call', 'voz de contacto de adulto.', ' 2 song types', ' imitações.', 'territorial song? early morning', ' taking off', 'no idea', 'chasing call', ' duet call', ' excited calls of 2 birds after playback', ' call or song', ' whistles', ' take-off calls', ' short', ' then song', ' tapping', 'canto/chamado', 'voz de contacto de pichón.', ' ?', ' imitando a Accipiter bicolor', ' song in flight', ' song (2 types)', ' wingbeats', 'fligth song', ' trill call', ' alternate song', ' Canto noturno', ' calls by pair in flight', ' duo', ' triple call', ' wing sounds', ' song 2', ' alarm calls.', " haven't heard this before in this sp", 'llamado', ' call/song', ' display wing-flutter', 'mating call', ' excited calls in flight', ' scream series', ' imitation of other species', 'flight song', ' sicalis flaveol', ' Psits', 'couple in copulation', ' attack calls', ' calls by same group', " 'chiguan' call", ' song. rolls.', ' calls or song', ' calls by 2 pairs in flight', 'growl cooing', ' squabble in flight', ' alarm call', ' rain', 'clicking', ' immature song', ' interaction vocalization', ' morning chorus', ' long', ' Territorial call', ' autos en la ruta. cars in the route', 'advertisement call', ' dawn duet', ' a harsh noisy call with pitch range 1-12 kHz lasting', ' daytime duet calls', 'lek', ' calls by presumed pair', ' rattle song', ' song (variant)', ' song-like call', ' also doing cracks (estalos in port.)', ' calls (2 types)', ' call of a juvenile', ' duet', ' beak sounds', ' su', ' disturbance note or alarm call', 'duet?', ' displaying', ' flight calls of 16 pairs', ' immature calls', ' Polioptila dumicola', ' nyctibeus griseus', ' two birds', 'wing flaps', ' various different calls and song', ' churring song', 'tamborileo', 'dawn song', 'chatter after playback', ' short songs', ' rolling call', ' calls by flushed flock', ' wing whirrs', 'call?', 'imitation', 'interaction call', ' song (variation)', ' cow', ' calls of a pair', ' anxiety calls', ' natural song', ' song and duet', ' single call note', 'chorus', ' song after playback', 'individuo criado en laboratorio. sonido al momento de ser alimentado.', ' predawn song', 'contact call', ' duet.', ' communal murmuring of flock', ' "subsong"', 'bater de asas', " 'laughing' song", ' perched', 'chamado', ' call of adult female', ' then in flight', ' then take-off call', ' wing flaps', ' lekk song', " trisyllabic 'sueee' calls", ' Batido de asas', 'rattle', 'wing beat', " 'purweer' song", 'flight chorus', ' alarm call of an adult', 'lekking', 'hiss', ' nocturnal flight call', ' clicks', ' camera zoom/shutter', ' unusual calls', ' canto al amanecer', ' Distress call in hand', ' voces humanas y música.', ' call from perch', ' perched and in flight', 'whistles', ' excited call', ' scolding', ' bill snaps', ' batido de asas', ' (flight?) calls', ' aggressive call', ' mating calls', ' agitated song in flight', 'song', ' fligth song', 'tapping', ' human voice', ' dawn call', ' variation song', ' pb', 'calling in flight', ' complex song', ' flight call', " 'cascade' and song", ' alarm call of 4 birds', 'bill snapping', ' anxiety call', ' Complex song', ' Take-off calls', ' pheugopedius mystacalis', ' agitated song', ' fight calls and sounds', ' couple communication', ' response to playback', 'wing sound', ' alarm calls when flushed', 'mechanical', ' (song-like) call', 'drum', ' rattle', ' bird in h', ' llamadas de contacto', ' alarm? call', ' interaction call', ' call variation', ' calls song', ' canto', ' Song 2. "Atípico".', 'alarm calls?', ' call and whistle', ' group call', ' "micrastur semitorquatus like" song', ' urban sounds', ' songs a and b and calls', 'all', ' communal murmuring', ' long rattling call', ' snaps', 'territorial call', ' call and song in flight', 'begging call', ' carro',  ...

# %%
print(
    f"Percentage of train audio with type: {(df_train['type'] != '[]').sum() / len(df_train) * 100:.2f}%"
)
# Out:
# Percentage of train audio with type: 63.50%

# %%
df_taxonomy
# Out:
#     primary_label  inat_taxon_id           scientific_name  \
# 0         1161364        1161364              Guyalna cuta
# 1          116570         116570             Caiman yacare
# 2         1176823        1176823    Leptodactylus luctator
# 3         1491113        1491113         Adenomera guarani
# 4         1595929        1595929         Lysapsus limellum
# ..            ...            ...                       ...
# 229       yebela1          16714       Elaenia flavogaster
# 230        yecmac          73272      Primolius auricollis
# 231        yecpar          19215        Brotogeris chiriri
# 232       yehcar1        1432779       Daptrius chimachima
# 233       yeofly1          16567  Tolmomyias sulphurescens
#
#                     common_name class_name
# 0                  Guyalna cuta    Insecta
# 1    Southern Spectacled Caiman   Reptilia
# 2                 Wrestler Frog   Amphibia
# 3      Guaraní leaf-litter frog   Amphibia
# 4        Uruguay Harlequin Frog   Amphibia
# ..                          ...        ...
# 229      Yellow-bellied Elaenia       Aves
# 230       Golden-collared Macaw       Aves
# 231   Yellow-chevroned Parakeet       Aves
# 232      Yellow-headed Caracara       Aves
# 233       Yellow-olive Flatbill       Aves
#
# [234 rows x 5 columns]

# %% [markdown]
# For now I will just use a `LabelEncoder` from Scikit-learn to encode the primary label. I fit the encoder on `df_taxonomy` since there are some animals that are only in either `train_audio` or `train_soundscapes`.

# %%
from sklearn.preprocessing import MultiLabelBinarizer

le_classes = MultiLabelBinarizer()
le_primary = MultiLabelBinarizer()

le_classes.fit(df_taxonomy["class_name"].apply(lambda x: [x]))
le_primary.fit(df_taxonomy["primary_label"].apply(lambda x: [x]))

print(f"Number of Classes: {len(le_classes.classes_)}")
print(f"Number of Species: {len(le_primary.classes_)}")
# Out:
# Number of Classes: 5
# Number of Species: 234

# %%
df_taxonomy
# Out:
#     primary_label  inat_taxon_id           scientific_name  \
# 0         1161364        1161364              Guyalna cuta
# 1          116570         116570             Caiman yacare
# 2         1176823        1176823    Leptodactylus luctator
# 3         1491113        1491113         Adenomera guarani
# 4         1595929        1595929         Lysapsus limellum
# ..            ...            ...                       ...
# 229       yebela1          16714       Elaenia flavogaster
# 230        yecmac          73272      Primolius auricollis
# 231        yecpar          19215        Brotogeris chiriri
# 232       yehcar1        1432779       Daptrius chimachima
# 233       yeofly1          16567  Tolmomyias sulphurescens
#
#                     common_name class_name
# 0                  Guyalna cuta    Insecta
# 1    Southern Spectacled Caiman   Reptilia
# 2                 Wrestler Frog   Amphibia
# 3      Guaraní leaf-litter frog   Amphibia
# 4        Uruguay Harlequin Frog   Amphibia
# ..                          ...        ...
# 229      Yellow-bellied Elaenia       Aves
# 230       Golden-collared Macaw       Aves
# 231   Yellow-chevroned Parakeet       Aves
# 232      Yellow-headed Caracara       Aves
# 233       Yellow-olive Flatbill       Aves
#
# [234 rows x 5 columns]

# %% [markdown]
# Since we only have primary labels and not class names in `df_train_soundscapes` we have a mapping from primary label to class name.

# %%
primary_to_class = {}
for primary_label, class_name in zip(
    df_taxonomy["primary_label"], df_taxonomy["class_name"]
):
    primary_to_class[primary_label] = class_name

# %%
from datetime import datetime


def time_to_seconds(t):
    dt = datetime.strptime(t, "%H:%M:%S")
    return 3600 * dt.hour + 60 * dt.minute + dt.second


x_train_files = df_train[["filename"]]
x_train_soundscapes_files = df_train_soundscapes[["filename", "start", "end"]]
x_train_soundscapes_files["start"] = x_train_soundscapes_files["start"].apply(
    time_to_seconds
)
x_train_soundscapes_files["end"] = x_train_soundscapes_files["end"].apply(
    time_to_seconds
)
x_train_soundscapes_files
# Out:
#                                        filename  start  end
# 0     BC2026_Train_0039_S22_20211231_201500.ogg      0    5
# 1     BC2026_Train_0039_S22_20211231_201500.ogg      5   10
# 2     BC2026_Train_0039_S22_20211231_201500.ogg     10   15
# 3     BC2026_Train_0039_S22_20211231_201500.ogg     15   20
# 4     BC2026_Train_0039_S22_20211231_201500.ogg     20   25
# ...                                         ...    ...  ...
# 1473  BC2026_Train_0055_S22_20220219_200000.ogg     35   40
# 1474  BC2026_Train_0055_S22_20220219_200000.ogg     40   45
# 1475  BC2026_Train_0055_S22_20220219_200000.ogg     45   50
# 1476  BC2026_Train_0055_S22_20220219_200000.ogg     50   55
# 1477  BC2026_Train_0055_S22_20220219_200000.ogg     55   60
#
# [1478 rows x 3 columns]

# %%
y_train_classes = le_classes.transform(df_train["class_name"].apply(lambda x: [x]))
print(y_train_classes.shape)

y_train_primary = le_primary.transform(df_train["primary_label"].apply(lambda x: [x]))
print(y_train_primary.shape)
# Out:
# (35549, 5)
# (35549, 234)

# %%
y_soundscapes_classes = le_classes.transform(
    df_train_soundscapes["primary_label"]
    .apply(lambda x: x.split(";"))
    .apply(lambda x: list({primary_to_class[primary_label] for primary_label in x}))
)
print(y_soundscapes_classes.shape)

y_soundscapes_primary = le_primary.transform(
    df_train_soundscapes["primary_label"].apply(lambda x: x.split(";"))
)
print(y_soundscapes_primary.shape)
# Out:
# (1478, 5)
# (1478, 234)

# %% [markdown]
# Our functions for analyzing the sounds should probably take as input a row from either `x_train` or `x_train_soundscapes`.

# %%
x_train_soundscapes_files.iloc[:10]
# Out:
#                                     filename  start  end
# 0  BC2026_Train_0039_S22_20211231_201500.ogg      0    5
# 1  BC2026_Train_0039_S22_20211231_201500.ogg      5   10
# 2  BC2026_Train_0039_S22_20211231_201500.ogg     10   15
# 3  BC2026_Train_0039_S22_20211231_201500.ogg     15   20
# 4  BC2026_Train_0039_S22_20211231_201500.ogg     20   25
# 5  BC2026_Train_0039_S22_20211231_201500.ogg     25   30
# 6  BC2026_Train_0039_S22_20211231_201500.ogg     30   35
# 7  BC2026_Train_0039_S22_20211231_201500.ogg     35   40
# 8  BC2026_Train_0039_S22_20211231_201500.ogg     40   45
# 9  BC2026_Train_0039_S22_20211231_201500.ogg     45   50

# %% [markdown]
# The example function below is how I think it can be good to write functions for finding features from the data.

# %%
# example function for getting features
def example_analysis(x):
    if x.shape == (1,):  # Audio
        audio, sr = librosa.load(
            f"../birdclef-2026/train_audio/{x['filename']}", sr=32000
        )
    elif x.shape == (3,):  # Soundscape
        audio, sr = librosa.load(
            f"../birdclef-2026/train_soundscapes/{x['filename']}",
            sr=32000,
            offset=x["start"],
            duration=x["end"] - x["start"],
        )
    else:
        raise ValueError

    # plt.title(f"{x['filename']}")
    S = np.abs(librosa.stft(audio))
    S_db = librosa.amplitude_to_db(S)
    # librosa.display.specshow(S_db)
    # plt.show()

    return pd.Series({"spec_min": S_db.min(), "spec_max": S_db.max()})

# %% [markdown]
# Takes about ~20 mins to load the whole dataset (can probably be improved)

# %%
from tqdm import tqdm
import warnings

warnings.filterwarnings("ignore", module="librosa")

features = pd.DataFrame(
    [
        example_analysis(row)
        for _, row in tqdm(x_train_files.iterrows(), total=len(x_train_files))
    ]
)
